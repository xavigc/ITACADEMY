# %%
# !pip search mysql-connector | grep --color mysql-connector-python
#!pip3 show mysql-connector-python
#!pip3 uninstall mysql-connector-python
#!pip install mysql-connector-python==8.0.11
#!pip3 install --upgrade mysql-connector-python
# Out:
# "grep" no se reconoce como un comando interno o externo,
# programa o archivo por lotes ejecutable.

# %%
#!pip uninstall mysql-connector-python
#!pip install mysql-connector-python==8.0.11
#!pip3 install mysql-connector-python

# !pip3 show mysql-connector-python
import sys
print(sys.version)
import pandas as pd
import mysql.connector
from mysql.connector import connect

Username =  'root'
Password = 'root'
Hostname ='localhost'
Databasename = 'XaviBD'

connect(user=Username, password=Password, host=Hostname, database=Databasename)
# Out:
# Name: mysql-connector-python
# Version: 9.5.0
# Summary: A self-contained Python driver for communicating with MySQL servers, using an API that is compliant with the Python Database API Specification v2.0 (PEP 249).
# Home-page: https://dev.mysql.com/doc/connector-python/en/
# Author: Oracle and/or its affiliates
# Author-email:
# License: GNU GPLv2 (with FOSS License Exception)
# Location: C:\Users\formacio\AppData\Roaming\Python\Python312\site-packages
# Requires:
# Required-by:
# 3.13.7 (tags/v3.13.7:bcee1c3, Aug 14 2025, 14:15:11) [MSC v.1944 64 bit (AMD64)]
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 9
#       7 print(sys.version)
#       8 import pandas as pd
# ----> 9 import mysql.connector
#      10 from mysql.connector import connect
#      12 Username =  'root'
#
# ModuleNotFoundError: No module named 'mysql'

# %%
# !pip3 show mysql-connector-python
# !pip3 uninstall mysql-connector-python
#!pip install mysql-connector-python==8.0.11
#!pip3 install mysql-connector-python
# Out:
# Name: mysql-connector-python
# Version: 8.0.11
# Summary: MySQL driver written in Python
# Home-page: http://dev.mysql.com/doc/connector-python/en/index.html
# Author: Oracle and/or its affiliates
# Author-email: UNKNOWN
# License: GNU GPLv2 (with FOSS License Exception)
# Location: C:\Users\formacio\AppData\Roaming\Python\Python312\site-packages
# Requires: protobuf
# Required-by:
# ^C
